# %%
import pandas_datareader.data as pdr
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
# %matplotlib inline

# %%
df = pd.read_csv("D:/JAINAM/BankNifty_16.csv", index_col='Date', parse_dates=True)
df
# Out:
#                 Open      High       Low     Close
# Date
# 2006-11-13   5773.25   5823.95   5730.85   5801.35
# 2006-11-16   6039.20   6268.25   6039.20   6175.05
# 2006-11-17   6166.45   6228.25   6066.15   6119.65
# 2006-11-20   6115.95   6115.95   5907.45   6006.60
# 2006-11-21   6045.05   6101.80   6009.10   6085.50
# ...              ...       ...       ...       ...
# 2023-01-03  43151.45  43482.80  43148.45  43425.25
# 2023-01-04  43417.50  43578.40  42858.65  42958.80
# 2023-01-05  43073.05  43137.55  42298.60  42608.70
# 2023-01-06  42649.70  42685.90  41877.00  42188.80
# 2023-01-09  42404.85  42716.80  42186.55  42582.75
#
# [3960 rows x 4 columns]

# %% [raw]
# df1 = pd.read_csv("D:/JAINAM/Nifty_23.csv", index_col='Date', parse_dates=True)
# df1.dropna(inplace=True)

# %% [raw]
# df1

# %%
df['Close'].plot(label = "Bank Nifty Closing", figsize=(15,7))
plt.title("Bank Nifty Stock Prices")
plt.ylabel("Stock Prices")
plt.legend()
plt.show()

# %%
df['Close'].plot(figsize=(15,7))
df['MA50'] = df['Close'].rolling(50).mean()
df['MA50'].plot(label = "MA50")
#df['MA100'] = df['Close'].rolling(100).mean()
#df['MA100'].plot(label = "MA100")
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [raw]
# df['Close'].plot(figsize=(15,7))
# #df['MA50'] = df['Close'].rolling(50).mean()
# #df['MA50'].plot(label = "MA50")
# df['MA100'] = df['Close'].rolling(100).mean()
# df['MA100'].plot(label = "MA100")

# %% [raw]
# df['Close'].plot(figsize=(15,7))
# df['MA500'] = df['Close'].rolling(500).mean()
# df['MA500'].plot(label = "MA500")

# %%
df['Close'].plot(figsize=(15,7))
df['MA250'] = df['Close'].rolling(250).mean()
df['MA250'].plot(label = "MA250")
# Out:
# <AxesSubplot:xlabel='Date'>
